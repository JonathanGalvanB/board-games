# %%
import pandas as pd
import numpy as np
import time 

from bs4 import BeautifulSoup

import requests

from bs4 import Comment

from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
url="https://boardgamegeek.com/boardgame/233078/twilight-imperium-fourth-edition/credits#boardgamemechanic"

# %%
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--disable-extensions")


driver = webdriver.Chrome(options=chrome_options)

# %%
sel = '#mainbody > div.global-body-content-container.container-fluid > div > div.content.ng-isolate-scope > div:nth-child(2) > ng-include > div > div > ui-view > ui-view > div > div > div.panel-body > credits-module > ul > li:nth-child(15) > div.outline-item-description > div'

# %%
db = pd.read_csv('database_duration_and_weight.csv', index_col=0)

# %%
mechanics1 = []

# %%
i=0
for link in db['Link'][:200]:
        #time.sleep(1)
        driver.get(link+'/credits#boardgamemechanic')
        try:
            mechanic = []
            element = WebDriverWait(driver, 3).until(EC.visibility_of_element_located((By.CSS_SELECTOR, sel)))
            list1 = element.find_elements(By.TAG_NAME,'a')
            for l in list1:
                mechanic.append(l.get_attribute('innerHTML'))
            mechanics1.append(mechanic)
            i+=1
            print(link+'/credits#boardgamemechanic',i, mechanic[0])
        except:
            mechanics1.append([])
            print('not found')
driver.quit()
# Out:
# https://boardgamegeek.com/boardgame/224517/brass-birmingham/credits#boardgamemechanic 1 Hand Management
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 i=0
#       2 for link in db['Link'][:200]:
#       3         #time.sleep(1)
# ----> 4         driver.get(link+'/credits#boardgamemechanic')
#       5         try:
#       6             mechanic = []
#
# File c:\Users\Jonat\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:454, in WebDriver.get(self, url)
#     436 def get(self, url: str) -> None:
#     437     """Navigate the browser to the specified URL in the current window or
#     438     tab.
#     439
#    (...)
#     452     >>> driver.get("https://example.com")
#     453     """
# --> 454     self.execute(Command.GET, {"url": url})
#
# ...

# %%
mech1 = pd.Series(mechanics1)

# %%
mech1.to_csv('mechanics_1_to_200.csv')

# %%
driver = webdriver.Chrome(options=chrome_options)
mechanics2 = []
i=0
for link in db['Link'][200:400]:
        #time.sleep(1)
        driver.get(link+'/credits#boardgamemechanic')
        try:
            mechanic = []
            element = WebDriverWait(driver, 3).until(EC.visibility_of_element_located((By.CSS_SELECTOR, sel)))
            list1 = element.find_elements(By.TAG_NAME,'a')
            for l in list1:
                mechanic.append(l.get_attribute('innerHTML'))
            mechanics2.append(mechanic)
            i+=1
            print(link+'/credits#boardgamemechanic',i, mechanic[0])
        except:
            mechanics2.append([])
            print(link+'/credits#boardgamemechanic','not found AAAAAAAAAAAAAAAAAAAAA')
driver.quit()
# Out:
# https://boardgamegeek.com/boardgame/104162/descent-journeys-in-the-dark-second-edition/credits#boardgamemechanic 1 Action Points
# https://boardgamegeek.com/boardgame/227224/the-red-cathedral/credits#boardgamemechanic 2 Area Majority / Influence
# https://boardgamegeek.com/boardgame/25021/sekigahara-the-unification-of-japan/credits#boardgamemechanic 3 Action Points
# https://boardgamegeek.com/boardgame/39463/cosmic-encounter/credits#boardgamemechanic 4 Alliances
# https://boardgamegeek.com/boardgame/314491/meadow/credits#boardgamemechanic 5 Hand Management
# https://boardgamegeek.com/boardgame/410201/wyrmspan/credits#boardgamemechanic 6 End Game Bonuses
# https://boardgamegeek.com/boardgame/155426/castles-of-mad-king-ludwig/credits#boardgamemechanic 7 End Game Bonuses
# https://boardgamegeek.com/boardgame/199561/sagrada/credits#boardgamemechanic 8 Contracts
# https://boardgamegeek.com/boardgame/282524/horrified/credits#boardgamemechanic 9 Action Points
# ...

# %%
mech2 = pd.Series(mechanics2)
mech2.to_csv('mechanics_201_to_400.csv')

# %%
driver = webdriver.Chrome(options=chrome_options)
mechanics3 = []
i=0
for link in db['Link'][400:600]:
        #time.sleep(1)
        driver.get(link+'/credits#boardgamemechanic')
        try:
            mechanic = []
            element = WebDriverWait(driver, 3).until(EC.visibility_of_element_located((By.CSS_SELECTOR, sel)))
            list1 = element.find_elements(By.TAG_NAME,'a')
            for l in list1:
                mechanic.append(l.get_attribute('innerHTML'))
            mechanics3.append(mechanic)
            i+=1
            print(link+'/credits#boardgamemechanic',i, mechanic[0])
        except:
            mechanics3.append([])
            print(link+'/credits#boardgamemechanic','not found AAAAAAAAAAAAAAAAAAAAA')
driver.quit()
# Out:
# https://boardgamegeek.com/boardgame/37046/ghost-stories/credits#boardgamemechanic 1 Cooperative Game
# https://boardgamegeek.com/boardgame/222509/lords-of-hellas/credits#boardgamemechanic 2 Area Majority / Influence
# https://boardgamegeek.com/boardgame/41114/the-resistance/credits#boardgamemechanic 3 Hidden Roles
# https://boardgamegeek.com/boardgame/119890/agricola-all-creatures-big-and-small/credits#boardgamemechanic 4 Automatic Resource Growth
# https://boardgamegeek.com/boardgame/308119/pax-renaissance-2nd-edition/credits#boardgamemechanic 5 Action Points
# https://boardgamegeek.com/boardgame/192458/51st-state-master-set/credits#boardgamemechanic 6 Hand Management
# https://boardgamegeek.com/boardgame/8217/san-juan/credits#boardgamemechanic 7 Action Drafting
# https://boardgamegeek.com/boardgame/163745/star-wars-armada/credits#boardgamemechanic 8 Action Queue
# ...

# %%
mech3 = pd.Series(mechanics3)
mech3.to_csv('mechanics_401_to_600.csv')

# %%
driver = webdriver.Chrome(options=chrome_options)
mechanics4 = []
i=0
for link in db['Link'][600:800]:
        #time.sleep(1)
        driver.get(link+'/credits#boardgamemechanic')
        try:
            mechanic = []
            element = WebDriverWait(driver, 3).until(EC.visibility_of_element_located((By.CSS_SELECTOR, sel)))
            list1 = element.find_elements(By.TAG_NAME,'a')
            for l in list1:
                mechanic.append(l.get_attribute('innerHTML'))
            mechanics4.append(mechanic)
            i+=1
            print(link+'/credits#boardgamemechanic',i, mechanic[0])
        except:
            mechanics4.append([])
            print(link+'/credits#boardgamemechanic','not found AAAAAAAAAAA')
driver.quit()

mech4 = pd.Series(mechanics4)
mech4.to_csv('mechanics_601_to_800.csv')
# Out:
# https://boardgamegeek.com/boardgame/221965/the-fox-in-the-forest/credits#boardgamemechanic 1 Hand Management
# https://boardgamegeek.com/boardgame/293296/splendor-marvel/credits#boardgamemechanic 2 Contracts
# https://boardgamegeek.com/boardgame/127398/legends-of-andor/credits#boardgamemechanic 3 Area Movement
# https://boardgamegeek.com/boardgame/90419/airlines-europe/credits#boardgamemechanic 4 Investment
# https://boardgamegeek.com/boardgame/163968/elysium/credits#boardgamemechanic 5 Open Drafting
# https://boardgamegeek.com/boardgame/318009/dinosaur-island-rawr-n-write/credits#boardgamemechanic 6 Connections
# https://boardgamegeek.com/boardgame/105551/archipelago/credits#boardgamemechanic 7 Area Majority / Influence
# https://boardgamegeek.com/boardgame/170561/valeria-card-kingdoms/credits#boardgamemechanic 8 Dice Rolling
# https://boardgamegeek.com/boardgame/248490/atlantis-rising-second-edition/credits#boardgamemechanic 9 Cooperative Game
# ...

# %%
driver = webdriver.Chrome(options=chrome_options)
mechanics5 = []
i=0
for link in db['Link'][800:]:
        #time.sleep(1)
        driver.get(link+'/credits#boardgamemechanic')
        try:
            mechanic = []
            element = WebDriverWait(driver, 3).until(EC.visibility_of_element_located((By.CSS_SELECTOR, sel)))
            list1 = element.find_elements(By.TAG_NAME,'a')
            for l in list1:
                mechanic.append(l.get_attribute('innerHTML'))
            mechanics5.append(mechanic)
            i+=1
            print(link+'/credits#boardgamemechanic',i, mechanic[0])
        except:
            #mechanics5.append([])
            print('not found AAAAAAAAAAA')
driver.quit()

mech5 = pd.Series(mechanics5)
mech5.to_csv('mechanics_801_to_1000.csv')
# Out:
# https://boardgamegeek.com/boardgame/20100/wits-and-wagers/credits#boardgamemechanic 1 Betting and Bluffing
# https://boardgamegeek.com/boardgame/143741/bang-the-dice-game/credits#boardgamemechanic 2 Dice Rolling
# https://boardgamegeek.com/boardgame/162007/steampunk-rally/credits#boardgamemechanic 3 Closed Drafting
# https://boardgamegeek.com/boardgame/23540/shikoku-1889/credits#boardgamemechanic 4 Auction / Bidding
# https://boardgamegeek.com/boardgame/226320/my-little-scythe/credits#boardgamemechanic 5 Area Majority / Influence
# https://boardgamegeek.com/boardgame/238799/messina-1347/credits#boardgamemechanic 6 Grid Movement
# https://boardgamegeek.com/boardgame/214880/city-of-the-big-shoulders/credits#boardgamemechanic 7 Commodity Speculation
# https://boardgamegeek.com/boardgame/280480/crystal-palace/credits#boardgamemechanic 8 End Game Bonuses
# https://boardgamegeek.com/boardgame/148729/maquis/credits#boardgamemechanic 9 Solo / Solitaire Game
# ...

# %%
len(mechanics5)
# Out:
# 200

# %%
len(db['Link'][800:])
# Out:
# 200

# %%
s1 = pd.read_csv('mechanics_1_to_200.csv', index_col=0)
s2 = pd.read_csv('mechanics_201_to_400.csv', index_col=0)
s3 = pd.read_csv('mechanics_401_to_600.csv', index_col=0)
s4 = pd.read_csv('mechanics_601_to_800.csv', index_col=0)
s5 = pd.read_csv('mechanics_801_to_1000.csv', index_col=0)

# %%
stacked_s = pd.concat([s1,s2,s3,s4,s5], axis=0, ignore_index=True)

# %%
len(stacked_s)
# Out:
# 1000

# %%
stacked_s.head()
# Out:
#                                                    0
# 0  ['Hand Management', 'Income', 'Loans', 'Market...
# 1  ['Action Points', 'Cooperative Game', 'Hand Ma...
# 2  ['Action Queue', 'Action Retrieval', 'Campaign...
# 3  ['Action Queue', 'End Game Bonuses', 'Grid Cov...
# 4  ['Action Drafting', 'Area-Impulse', 'Dice Roll...

# %%
stacked_s.name='mechanics'

# %%
db.head()
# Out:
#                                 Name  Rank  \
# 0                  Brass: Birmingham     1
# 1          Pandemic Legacy: Season 1     2
# 2                         Gloomhaven     3
# 3                           Ark Nova     4
# 4  Twilight Imperium: Fourth Edition     5
#
#                                                 Link  Geek Rating  \
# 0  https://boardgamegeek.com/boardgame/224517/bra...        8.413
# 1  https://boardgamegeek.com/boardgame/161936/pan...        8.376
# 2  https://boardgamegeek.com/boardgame/174430/glo...        8.344
# 3  https://boardgamegeek.com/boardgame/342942/ark...        8.340
# 4  https://boardgamegeek.com/boardgame/233078/twi...        8.237
#
#    Average ratings   Voters  min_layers max_layers min_duration max_duration  \
# 0             8.59  48020.0           2          4           60          120
# 1             8.52  54158.0           2          4           60           na
# ...

# %%
db1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 db1.head()
#
# NameError: name 'db1' is not defined

# %%
mechanics = mechanics1+mechanics2+mechanics3+mechanics4+mechanics5

# %%
mechanics[1]
# Out:
# ['Action Points',
#  'Cooperative Game',
#  'Hand Management',
#  'Legacy Game',
#  'Point to Point Movement',
#  'Scenario / Mission / Campaign Game',
#  'Set Collection',
#  'Tags',
#  'Trading',
#  'Variable Player Powers']

# %%
db.head()
# Out:
#                                 Name  Rank  \
# 0                  Brass: Birmingham     1
# 1          Pandemic Legacy: Season 1     2
# 2                         Gloomhaven     3
# 3                           Ark Nova     4
# 4  Twilight Imperium: Fourth Edition     5
#
#                                                 Link  Geek Rating  \
# 0  https://boardgamegeek.com/boardgame/224517/bra...        8.413
# 1  https://boardgamegeek.com/boardgame/161936/pan...        8.376
# 2  https://boardgamegeek.com/boardgame/174430/glo...        8.344
# 3  https://boardgamegeek.com/boardgame/342942/ark...        8.340
# 4  https://boardgamegeek.com/boardgame/233078/twi...        8.237
#
#    Average ratings   Voters  min_layers max_layers min_duration max_duration  \
# 0             8.59  48020.0           2          4           60          120
# 1             8.52  54158.0           2          4           60           na
# ...

# %%
db['mechanics'] = mechanics

# %%
db['mechanics'][0][2]
# Out:
# 'Loans'

# %%
db.rename(columns={'min_layers': 'min_players','max_layers': 'max_players'}, inplace=True)

# %%
db.to_json('database_1000.json')
