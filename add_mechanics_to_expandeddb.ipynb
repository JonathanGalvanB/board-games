# %%
import pandas as pd
import numpy as np
import time 

from bs4 import BeautifulSoup

import requests

from bs4 import Comment

from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--disable-extensions")


driver = webdriver.Chrome(options=chrome_options)

# %%
sel = '#mainbody > div.global-body-content-container.container-fluid > div > div.content.ng-isolate-scope > div:nth-child(2) > ng-include > div > div > ui-view > ui-view > div > div > div.panel-body > credits-module > ul > li:nth-child(15) > div.outline-item-description > div'

# %%
db = pd.read_csv('expanded_database_1_to_10000.csv', index_col=0)
db.head()
# Out:
#        id                               name  \
# 0  224517                  Brass: Birmingham
# 1  161936          Pandemic Legacy: Season 1
# 2  342942                           Ark Nova
# 3  174430                         Gloomhaven
# 4  233078  Twilight Imperium: Fourth Edition
#
#                                          Link Min_players Max_players  \
# 0  https://boardgamegeek.com/boardgame/224517           2           4
# 1  https://boardgamegeek.com/boardgame/161936           2           4
# 2  https://boardgamegeek.com/boardgame/342942           1           4
# 3  https://boardgamegeek.com/boardgame/174430           1           4
# 4  https://boardgamegeek.com/boardgame/233078           3           6
#
#   Min_duration Max_duration Weight
# 0           60          120   3.87
# 1           60           na   2.83
# 2           90          150   3.78
# 3           60          120   3.91
# 4          240          480   4.33

# %%
driver = webdriver.Chrome(options=chrome_options)
new_links = []
game_sel = '#mainbody > div.global-body-content-container.container-fluid > div > div.content.ng-isolate-scope > div:nth-child(2) > ng-include > div > ng-include > div > div.game-header > div.game-header-body > div.game-header-title-container > div > div.game-header-title-info > hgroup > h1 > a'
i=0
for link in db['Link']:
        #time.sleep(1)
        driver.get(link)
        try:
            mechanic = []
            element = WebDriverWait(driver, 5).until(EC.visibility_of_element_located((By.CSS_SELECTOR, game_sel)))
            if element:
                new_link = 'https://boardgamegeek.com'+element.get_attribute('href')
                print(i,new_link)
                new_links.append(new_link)
            else:
                print('name not found?')


        except:
            print(i,link,'link not found AAAAAAAAAAAAAAAAAAAAA')
        i+=1
             
driver.quit()
# Out:
# 0 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/224517/brass-birmingham
# 1 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/161936/pandemic-legacy-season-1
# 2 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/342942/ark-nova
# 3 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/174430/gloomhaven
# 4 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/233078/twilight-imperium-fourth-edition
# 5 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/316554/dune-imperium
# 6 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/167791/terraforming-mars
# 7 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/115746/war-of-the-ring-second-edition
# 8 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/187645/star-wars-rebellion
# 9 https://boardgamegeek.comhttps://boardgamegeek.com/boardgame/162886/spirit-island
# ...
